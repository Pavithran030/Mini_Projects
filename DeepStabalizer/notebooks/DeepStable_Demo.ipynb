# %% [markdown]
# # DeepStable Demo\n
# Quick walkthrough notebook for synthetic data generation, model inference, and metric snapshots.

# %%
import sys, os\n
ROOT = os.path.abspath('..')\n
if ROOT not in sys.path:\n
    sys.path.insert(0, ROOT)\n
print('DeepStable demo notebook ready')
